# %% [markdown]
# <a href="https://colab.research.google.com/github/Manideep12/Manideep_pendem/blob/master/knowledgebase_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install llama-index
# !pip install langchain
#from gpt_index import SimpleDirectoryReader, GPTListIndex, GPTSimpleVectorIndex, LLMPredictor, PromptHelper
# !pip install PyPDF2
# !pip install PyCryptodome
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.0/630.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 39.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.1 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install openai

# %%
# Restart the kernel
# !kill -9 -1

# %%
# !pip install bigdl-llm

# %%
from langchain import OpenAI
from llama_index.simple_directory_reader import SimpleDirectoryReader
from llama_index.gpt_simple_vector_index import GPTSimpleVectorIndex
from llama_index.llm_predictor import LLMPredictor
from llama_index.prompts.prompt_helper import PromptHelper

from langchain_community.llms import ChatOpenAI

import gradio as gr
import os
import logging

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Constants
MAX_INPUT_SIZE = 4096
NUM_OUTPUTS = 512
MAX_CHUNK_OVERLAP = 20
CHUNK_SIZE_LIMIT = 600

# Environment variable for OpenAI API key
os.environ["OPENAI_API_KEY"] = 'sk-key'

def construct_index(directory_path, max_input_size=MAX_INPUT_SIZE, num_outputs=NUM_OUTPUTS,
                    max_chunk_overlap=MAX_CHUNK_OVERLAP, chunk_size_limit=CHUNK_SIZE_LIMIT):
    """
    Construct the GPTSimpleVectorIndex based on the provided parameters.

    Args:
        directory_path (str): Path to the directory containing training documents.
        max_input_size (int): Maximum size of input text.
        num_outputs (int): Number of output tokens.
        max_chunk_overlap (int): Maximum overlap between text chunks.
        chunk_size_limit (int): Limit on the size of text chunks.

    Returns:
        GPTSimpleVectorIndex: Constructed index.
    """
prompt_helper = PromptHelper(max_input_size, num_outputs, max_chunk_overlap, chunk_size_limit=chunk_size_limit)
llm_predictor = LLMPredictor(llm=ChatOpenAI(temperature=0))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-443063c69c23> in <cell line: 2>()
#       1 from langchain import OpenAI
# ----> 2 from llama_index.simple_directory_reader import SimpleDirectoryReader
#       3 from llama_index.gpt_simple_vector_index import GPTSimpleVectorIndex
#       4 from llama_index.llm_predictor import LLMPredictor
#       5 from llama_index.prompts.prompt_helper import PromptHelper
#
# /usr/local/lib/python3.10/dist-packages/llama_index/__init__.py in <module>
#      19
#      20 # structured
# ---> 21 from llama_index.indices.common.struct_store.base import SQLDocumentContextBuilder
#      22
#      23 # for composability
#
# /usr/local/lib/python3.10/dist-packages/llama_index/indices/__init__.py in <module>
#       2
#       3 # indices
# ----> 4 from llama_index.indices.document_summary.base import DocumentSummaryIndex
# ...

# %%
# !pip install llama-index
# !pip install langchain
#from gpt_index import SimpleDirectoryReader, GPTListIndex, GPTSimpleVectorIndex, LLMPredictor, PromptHelper
from langchain import OpenAI
from llama_index import SimpleDirectoryReader, LangchainEmbedding, GPTListIndex,GPTSimpleVectorIndex, PromptHelper
from llama_index import LLMPredictor, ServiceContext
import sys
#from google.colab import drive
import os

# Environment variable for OpenAI API key
os.environ["OPENAI_API_KEY"] = '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'

def construct_index(directory_path):
  # set maximum input size
  max_input_size = 4096
  # set number of output tokens
  num_outputs = 256
  # set maximum chunk overlap
  max_chunk_overlap = 20
  # set chunk size limit
  chunk_size_limit = 600

  prompt_helper = PromptHelper(max_input_size, num_outputs, max_chunk_overlap, chunk_size_limit=chunk_size_limit)

  # define LLM
  llm_predictor = LLMPredictor(llm=OpenAI(temperature=0, model_name="text-davinci-002", max_tokens=num_outputs))

  documents = SimpleDirectoryReader(directory_path).load_data()

  service_context = ServiceContext.from_defaults(llm_predictor=llm_predictor)
  index = GPTSimpleVectorIndex.from_documents(documents, service_context=service_context)

  index.save_to_disk('index.json')

  return index
def ask_bot(input_index = 'index.json'):
  index = GPTSimpleVectorIndex.load_from_disk(input_index)
  while True:
    query = input('What do you want to ask the bot?   \n')
    response = index.query(query, response_mode="compact")
    print ("\nBot says: \n\n" + response.response + "\n\n\n")

#!wget http://classics.mit.edu/Antoninus/meditations.mb.txt

# !wget https://www.gutenberg.org/ebooks/1.txt.utf-8
index = construct_index("/content/")
ask_bot('index.json')

# %% [markdown]
# # New Section
